# %% [markdown]
# # Método CRISP-DM aplicado a la predicción de precios de hogares en el área metropolitana

# %% [markdown]
# ## Entendimiento del Negocio
#
#
# https://eafit-my.sharepoint.com/:w:/g/personal/lagonzala1_eafit_edu_co/ETHPB5HNXmZKqmOdtcFGZR4BHfAYmSyKaGVeLXXzUd0zPQ?e=2G8KqK

# %% [markdown]
# ## Entendimiento de los datos
#
# ### Carga de datos:

# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
# %matplotlib inline
from matplotlib.pylab import rcParams
from datetime import datetime
import warnings
plt.rcParams.update({'font.size': 14})
warnings.filterwarnings('ignore')

# %%
df = pd.read_json("readydata.json")
df.head()
# Out:
#    ID de la propiedad Tipo de Operacion Tipo de Inmueble Departamento Ciudad  \
# 0           192788587             Venta      Apartamento    Antioquia  Bello
# 1           192805940             Venta      Apartamento    Antioquia  Bello
# 2           192833958             Venta      Apartamento    Antioquia  Bello
# 3           192839470             Venta      Apartamento    Antioquia  Bello
# 4           192852231             Venta             Casa    Antioquia  Bello
#
#   Localidad Principal Tipo de Localidad Principal  Metros Cuadrados  \
# 0              Niquia               neighbourhood              59.0
# 1           Andalucia               neighbourhood              64.9
# 2               Bello                        city              67.0
# 3               Bello                        city              72.0
# 4               Prado               neighbourhood              91.0
#
#    Metros Cuadrados Construidos  Estrato  ...  Es Oficina?  Es Penthouse?  \
# 0                           NaN        3  ...        False          False
# 1                          64.9        3  ...        False          False
# 2                           NaN        3  ...        False          False
# 3                          72.0        3  ...        False          False
# 4                          91.0        3  ...        False          False
#
#    Acepta Permuta?  (paid quota)?  Fecha de Creacion de Oferta  \
# 0            False           True                   2025-08-25
# 1            False           True                   2025-08-29
# 2            False           True                   2025-09-04
# 3            False           True                   2025-09-05
# 4            False           True                   2025-09-09
#
#    Fecha de Actualización de Oferta                                 Dirección  \
# 0                        2025-09-16     Apartamento en Venta en Niquia, Bello
# 1                        2025-08-29  Apartamento en Venta en Andalucia, Bello
# 2                        2025-10-30             Apartamento en Venta en Bello
# 3                        2025-09-20             Apartamento en Venta en Bello
# 4                        2025-09-29             Casa en Venta en Prado, Bello
#
#                                                  URL  \
# 0    /apartamento-en-venta-en-niquia-bello/192788587
# 1  /apartamento-en-venta-en-andalucia-bello/19280...
# 2           /apartamento-en-venta-en-bello/192833958
# 3           /apartamento-en-venta-en-bello/192839470
# 4            /casa-en-venta-en-prado-bello/192852231
#
#    Precio con Administración Incluida     Precio
# 0                           275000000  275000000
# 1                           280000000  280000000
# 2                           260241000  260000000
# 3                           433369521  433000000
# 4                           295000000  295000000
#
# [5 rows x 31 columns]

# %%
df.shape
# Out:
# (5827, 31)

# %%
df.describe()
# Out:
#        ID de la propiedad  Metros Cuadrados  Metros Cuadrados Construidos  \
# count        5.827000e+03       5785.000000                   4828.000000
# mean         1.894227e+08        149.676068                    130.790387
# std          2.453440e+07       1777.493584                    324.867469
# min          5.093501e+06          0.000000                      0.000000
# 25%          1.926759e+08         62.000000                     62.000000
# 50%          1.928929e+08         76.000000                     78.000000
# 75%          1.929936e+08        114.000000                    118.000000
# max          1.930546e+08     133377.000000                  11000.000000
#
#            Estrato      Latitud     Longitud  Antigüedad (Grupo)  \
# count  5827.000000  5827.000000  5827.000000         5703.000000
# mean      4.167496     6.199873   -75.596745            2.285113
# std       6.239423     0.100346     0.050384            1.314624
# min       0.000000     4.620578   -75.661438            0.000000
# 25%       3.000000     6.153324   -75.625082            2.000000
# 50%       4.000000     6.167528   -75.601615            2.000000
# 75%       4.000000     6.225058   -75.569930            3.000000
# max     110.000000    11.212865   -74.030012            5.000000
#
#        Cuartos (rooms)  Dormitorios (bedrooms)        Baños  Parqueaderos  \
# count      5827.000000             5827.000000  5827.000000   5827.000000
# mean          2.258109                2.889995     2.382015      1.143985
# std           1.451103                0.871457     1.001855      1.183491
# min           0.000000                0.000000     0.000000     -2.000000
# 25%           2.000000                2.000000     2.000000      0.000000
# 50%           3.000000                3.000000     2.000000      1.000000
# 75%           3.000000                3.000000     2.000000      1.000000
# max          15.000000               15.000000    10.000000     14.000000
#
#               Piso  Es Proyecto?  Precio con Administración Incluida  \
# count  5612.000000          13.0                        5.827000e+03
# mean      5.257662           1.0                        1.007876e+09
# std       6.845410           0.0                        1.175982e+10
# min      -1.000000           1.0                        3.900010e+05
# 25%       0.000000           1.0                        3.500000e+08
# 50%       2.000000           1.0                        4.922600e+08
# 75%      10.000000           1.0                        7.600000e+08
# max      97.000000           1.0                        6.300003e+11
#
#              Precio
# count  5.827000e+03
# mean   1.005765e+09
# std    1.175971e+10
# min    1.000000e+00
# 25%    3.500000e+08
# 50%    4.920000e+08
# 75%    7.535000e+08
# max    6.300000e+11

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5827 entries, 0 to 5826
# Data columns (total 31 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   ID de la propiedad                  5827 non-null   int64
#  1   Tipo de Operacion                   5827 non-null   object
#  2   Tipo de Inmueble                    5827 non-null   object
#  3   Departamento                        5827 non-null   object
#  4   Ciudad                              5827 non-null   object
#  5   Localidad Principal                 5823 non-null   object
#  6   Tipo de Localidad Principal         5823 non-null   object
#  7   Metros Cuadrados                    5785 non-null   float64
#  8   Metros Cuadrados Construidos        4828 non-null   float64
#  9   Estrato                             5827 non-null   int64
#  10  Latitud                             5827 non-null   float64
#  11  Longitud                            5827 non-null   float64
#  12  Antigüedad (Grupo)                  5703 non-null   float64
#  13  Cuartos (rooms)                     5827 non-null   int64
#  14  Dormitorios (bedrooms)              5827 non-null   int64
#  15  Baños                               5827 non-null   int64
#  16  Parqueaderos                        5827 non-null   int64
#  17  Piso                                5612 non-null   float64
#  18  Tiene Garage?                       5827 non-null   bool
#  19  Es Proyecto?                        13 non-null     float64
#  20  Es Unidad Projecto?                 5827 non-null   bool
#  21  Es Oficina?                         5827 non-null   bool
#  22  Es Penthouse?                       5827 non-null   bool
#  23  Acepta Permuta?                     5827 non-null   bool
#  24  (paid quota)?                       5827 non-null   bool
#  25  Fecha de Creacion de Oferta         5827 non-null   object
#  26  Fecha de Actualización de Oferta    5827 non-null   object
#  27  Dirección                           5827 non-null   object
#  28  URL                                 5827 non-null   object
#  29  Precio con Administración Incluida  5827 non-null   int64
#  30  Precio                              5827 non-null   int64
# dtypes: bool(6), float64(7), int64(8), object(10)
# memory usage: 1.2+ MB

# %% [markdown]
# Se ven cosas curiosas, como que el estrato de uno de los registros sea 110.
#
# De resto, las otras columnas aparentan ser normales, aunque los metros cuadrados y los pisos tienen una excepción extraña, donde el máximo parece ser de 133377. Eso es un resultado un poco loco, dado en cuenta que el tercer cuartil es de 114, y el piso máximo es el 97 (no se que edificio tiene 97 pisos en el valle de aburrá) y el mínimo es el -1, que podría ser un sótano o un error. Un precio máximo de 6.3 e11 también es muy muy muy elevado, altamente probable que este sea una anomalía.

# %% [markdown]
# ### Análisis de calidad de los datos

# %% [markdown]
# #### Completitud

# %%
df.isna().sum()
# Out:
# ID de la propiedad                       0
# Tipo de Operacion                        0
# Tipo de Inmueble                         0
# Departamento                             0
# Ciudad                                   0
# Localidad Principal                      4
# Tipo de Localidad Principal              4
# Metros Cuadrados                        42
# Metros Cuadrados Construidos           999
# Estrato                                  0
# Latitud                                  0
# Longitud                                 0
# Antigüedad (Grupo)                     124
# Cuartos (rooms)                          0
# Dormitorios (bedrooms)                   0
# Baños                                    0
# Parqueaderos                             0
# Piso                                   215
# Tiene Garage?                            0
# Es Proyecto?                          5814
# Es Unidad Projecto?                      0
# Es Oficina?                              0
# Es Penthouse?                            0
# Acepta Permuta?                          0
# (paid quota)?                            0
# Fecha de Creacion de Oferta              0
# Fecha de Actualización de Oferta         0
# Dirección                                0
# URL                                      0
# Precio con Administración Incluida       0
# Precio                                   0
# dtype: int64

# %% [markdown]
# Por lo que podemos ver, hay algunos registros vacíos, por lo tanto no está completo del todo. Sin embargo el dataset no tiene vacíos aparentes que puedan aportar más información acerca del precio del arriendo de los hogares.

# %% [markdown]
# #### Conformidad/Validez

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5827 entries, 0 to 5826
# Data columns (total 31 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   ID de la propiedad                  5827 non-null   int64
#  1   Tipo de Operacion                   5827 non-null   object
#  2   Tipo de Inmueble                    5827 non-null   object
#  3   Departamento                        5827 non-null   object
#  4   Ciudad                              5827 non-null   object
#  5   Localidad Principal                 5823 non-null   object
#  6   Tipo de Localidad Principal         5823 non-null   object
#  7   Metros Cuadrados                    5785 non-null   float64
#  8   Metros Cuadrados Construidos        4828 non-null   float64
#  9   Estrato                             5827 non-null   int64
#  10  Latitud                             5827 non-null   float64
#  11  Longitud                            5827 non-null   float64
#  12  Antigüedad (Grupo)                  5703 non-null   float64
#  13  Cuartos (rooms)                     5827 non-null   int64
#  14  Dormitorios (bedrooms)              5827 non-null   int64
#  15  Baños                               5827 non-null   int64
#  16  Parqueaderos                        5827 non-null   int64
#  17  Piso                                5612 non-null   float64
#  18  Tiene Garage?                       5827 non-null   bool
#  19  Es Proyecto?                        13 non-null     float64
#  20  Es Unidad Projecto?                 5827 non-null   bool
#  21  Es Oficina?                         5827 non-null   bool
#  22  Es Penthouse?                       5827 non-null   bool
#  23  Acepta Permuta?                     5827 non-null   bool
#  24  (paid quota)?                       5827 non-null   bool
#  25  Fecha de Creacion de Oferta         5827 non-null   object
#  26  Fecha de Actualización de Oferta    5827 non-null   object
#  27  Dirección                           5827 non-null   object
#  28  URL                                 5827 non-null   object
#  29  Precio con Administración Incluida  5827 non-null   int64
#  30  Precio                              5827 non-null   int64
# dtypes: bool(6), float64(7), int64(8), object(10)
# memory usage: 1.2+ MB

# %% [markdown]
# El formato para cada variable parece ser el correcto, sin embargo hay que revisar variable por variable su formato. Las fechas parecen estar bien.
# A continuación se muestran las columnas que tienen formato de fecha, y que formato tienen.

# %%
date_formats_report = []

for col in df.columns:
    if df[col].notna().sum() == 0:
        continue
    vals = df[col].dropna().astype(str)
    samples = vals.sample(min(50, len(vals)), random_state=1)
    parsed = pd.to_datetime(samples, errors='coerce', infer_datetime_format=True)
    if parsed.notna().mean() > 0.6:  # >60% parecen fechas
        formats = set()
        for v in samples:
            try:
                if "-" in v:
                    parts = v.split("-")
                    if len(parts)==3 and len(parts[0])==4:
                        formats.add("YYYY-MM-DD")
                    elif len(parts)==3 and len(parts[2])==4:
                        formats.add("DD-MM-YYYY")
                    else:
                        formats.add("other-with-dash")
                else:
                    formats.add("non-dash")
            except:
                formats.add("unknown")
        date_formats_report.append((col, list(formats)))

date_formats_report
# Out:
# [('Fecha de Creacion de Oferta', ['YYYY-MM-DD']),
#  ('Fecha de Actualización de Oferta', ['YYYY-MM-DD'])]

# %%
df[col].astype(str).str.contains("[^0-9\\.-]").any()
# Out:
# np.False_

# %% [markdown]
# No hay cosas raras en las columnas de string.

# %% [markdown]
# #### Consistencia

# %%
df[(df['Dormitorios (bedrooms)']> df['Cuartos (rooms)']  )]
# Out:
#       ID de la propiedad Tipo de Operacion Tipo de Inmueble Departamento  \
# 0              192788587             Venta      Apartamento    Antioquia
# 5              192868806             Venta      Apartamento    Antioquia
# 14             192886436             Venta      Apartamento    Antioquia
# 24             191997110             Venta      Apartamento    Antioquia
# 25             192961362             Venta             Casa    Antioquia
# ...                  ...               ...              ...          ...
# 5812           193001267             Venta      Apartamento    Antioquia
# 5813           193002785             Venta      Apartamento    Antioquia
# 5815           193001396             Venta      Apartamento    Antioquia
# 5816           193003287             Venta      Apartamento    Antioquia
# 5826           193024616             Venta      Apartamento    Antioquia
#
#            Ciudad Localidad Principal Tipo de Localidad Principal  \
# 0           Bello              Niquia               neighbourhood
# 5           Bello   Zona industrial 1               neighbourhood
# 14          Bello             Cabañas               neighbourhood
# 24          Bello    Sector belvedere               neighbourhood
# 25          Bello             Cabañas               neighbourhood
# ...           ...                 ...                         ...
# 5812  La estrella          La Tablaza               neighbourhood
# 5813  La estrella        Pueblo Viejo               neighbourhood
# 5815  La estrella         La ferreria               neighbourhood
# 5816       Caldas          La Tablaza               neighbourhood
# 5826  La estrella         La ferreria               neighbourhood
#
#       Metros Cuadrados  Metros Cuadrados Construidos  Estrato  ...  \
# 0                59.00                           NaN        3  ...
# 5                47.31                         47.31        4  ...
# 14               80.00                         80.00        4  ...
# 24               55.60                         55.60        3  ...
# 25               98.00                           NaN        4  ...
# ...                ...                           ...      ...  ...
# 5812             53.00                           NaN        3  ...
# 5813             51.00                           NaN        3  ...
# 5815             69.00                         69.00        4  ...
# 5816             38.00                           NaN        2  ...
# 5826             53.00                         53.00        4  ...
#
#       Es Oficina?  Es Penthouse?  Acepta Permuta?  (paid quota)?  \
# 0           False          False            False           True
# 5           False          False            False           True
# 14          False          False            False          False
# 24          False          False            False           True
# 25          False          False            False           True
# ...           ...            ...              ...            ...
# 5812        False          False            False           True
# 5813        False          False            False           True
# 5815        False          False            False           True
# 5816        False          False            False           True
# 5826        False          False            False           True
#
#       Fecha de Creacion de Oferta  Fecha de Actualización de Oferta  \
# 0                      2025-08-25                        2025-09-16
# 5                      2025-09-13                        2025-09-13
# 14                     2025-09-17                        2025-09-17
# 24                     2025-02-10                        2025-07-04
# 25                     2025-10-08                        2025-10-15
# ...                           ...                               ...
# 5812                   2025-10-20                        2025-10-31
# 5813                   2025-10-20                        2025-10-30
# 5815                   2025-10-20                        2025-10-20
# 5816                   2025-10-20                        2025-10-23
# 5826                   2025-10-24                        2025-10-24
#
#                                               Dirección  \
# 0                 Apartamento en Venta en Niquia, Bello
# 5      Apartamento en Venta en Zona industrial 1, Bello
# 14               Apartamento en Venta en Cabañas, Bello
# 24     Apartamento en  Venta en Sector belvedere, Bello
# 25                      Casa en Venta en Cabañas, Bello
# ...                                                 ...
# 5812    Apartamento en Venta en La Tablaza, La estrella
# 5813  Apartamento en Venta en Pueblo Viejo, La estrella
# 5815   Apartamento en Venta en La ferreria, La estrella
# 5816         Apartamento en Venta en La Tablaza, Caldas
# 5826   Apartamento en Venta en La ferreria, La estrella
#
#                                                     URL  \
# 0       /apartamento-en-venta-en-niquia-bello/192788587
# 5     /apartamento-en-venta-en-zona-industrial-1-bel...
# 14     /apartamento-en-venta-en-cabañas-bello/192886436
# 24    /apartamento-en-venta-en-sector-belvedere-bell...
# 25            /casa-en-venta-en-cabañas-bello/192961362
# ...                                                 ...
# 5812  /apartamento-en-venta-en-la-tablaza-la-estrell...
# 5813  /apartamento-en-venta-en-pueblo-viejo-la-estre...
# 5815  /apartamento-en-venta-en-la-ferreria-la-estrel...
# 5816  /apartamento-en-venta-en-la-tablaza-caldas/193...
# 5826  /apartamento-en-venta-en-la-ferreria-la-estrel...
#
#       Precio con Administración Incluida     Precio
# 0                              275000000  275000000
# 5                              320000000  320000000
# 14                             275000000  275000000
# 24                             300220000  300000000
# 25                             425000000  425000000
# ...                                  ...        ...
# 5812                           237210000  237000000
# 5813                           230152000  230000000
# 5815                           377300000  377000000
# 5816                           200140000  200000000
# 5826                           350197000  350000000
#
# [1307 rows x 31 columns]

# %% [markdown]
# Registros donde hay mas dormitorios que cuartos, lo cual se contradice

# %%
df[df['Metros Cuadrados'] < df['Metros Cuadrados Construidos'] ]
# Out:
# Empty DataFrame
# Columns: [ID de la propiedad, Tipo de Operacion, Tipo de Inmueble, Departamento, Ciudad, Localidad Principal, Tipo de Localidad Principal, Metros Cuadrados, Metros Cuadrados Construidos, Estrato, Latitud, Longitud, Antigüedad (Grupo), Cuartos (rooms), Dormitorios (bedrooms), Baños, Parqueaderos, Piso, Tiene Garage?, Es Proyecto?, Es Unidad Projecto?, Es Oficina?, Es Penthouse?, Acepta Permuta?, (paid quota)?, Fecha de Creacion de Oferta, Fecha de Actualización de Oferta, Dirección, URL, Precio con Administración Incluida, Precio]
# Index: []
#
# [0 rows x 31 columns]

# %%
from scipy.stats import chi2

# seleccionar variables numéricas relevantes
X = df[["Precio", "Metros Cuadrados", "Cuartos (rooms)", "Baños"]].dropna()

# calcular media y covarianza
mu = X.mean(axis=0)
cov = np.cov(X.values, rowvar=False)
inv_cov = np.linalg.inv(cov)

# distancia de Mahalanobis
diff = X - mu
md = np.sqrt(np.diag(diff @ inv_cov * diff.T))

# umbral según chi-cuadrado
threshold = np.sqrt(chi2.ppf(0.99, df=X.shape[1]))

# puntos incoherentes
inconsistentes = X[md > threshold]
print(X)
print(inconsistentes)
# Out:
#          Precio  Metros Cuadrados  Cuartos (rooms)  Baños
# 0     275000000              59.0                0      2
# 1     280000000              64.9                0      2
# 2     260000000              67.0                3      2
# 3     433000000              72.0                3      2
# 4     295000000              91.0                3      2
# ...         ...               ...              ...    ...
# 5822  350000000              53.0                2      2
# 5823  890000000             147.0                3      3
# 5824  230000000              48.0                2      1
# 5825  528000000              78.0                3      2
# 5826  350000000              53.0                0      2
#
# [5785 rows x 4 columns]
# Empty DataFrame
# Columns: [Precio, Metros Cuadrados, Cuartos (rooms), Baños]
# Index: []

# %% [markdown]
# No parece haber datos salidos de la elipse de mahalanobis

# %% [markdown]
# #### Precisión/Exactitud:

# %%
df[( df['Estrato']< 1 ) | (df['Estrato'] > 6 )]
# Out:
#       ID de la propiedad Tipo de Operacion Tipo de Inmueble Departamento  \
# 15             192945237             Venta      Apartamento    Antioquia
# 31             192010579             Venta      Apartamento    Antioquia
# 34             192020844             Venta      Apartamento    Antioquia
# 37             192010581             Venta      Apartamento    Antioquia
# 63             192971088             Venta      Apartamento    Antioquia
# ...                  ...               ...              ...          ...
# 5654           192846264             Venta             Casa    Antioquia
# 5741           192921734             Venta             Casa    Antioquia
# 5762           192985963             Venta      Apartamento    Antioquia
# 5779           192968035             Venta      Apartamento    Antioquia
# 5784           192972332             Venta             Casa    Antioquia
#
#            Ciudad Localidad Principal Tipo de Localidad Principal  \
# 15          Bello           Comuna 10                     commune
# 31          Bello              Centro               neighbourhood
# 34          Bello        Buenos aires               neighbourhood
# 37          Bello           Cabañitas               neighbourhood
# 63          Bello             Cabañas               neighbourhood
# ...           ...                 ...                         ...
# 5654  La estrella     Poblado Del Sur               neighbourhood
# 5741  La estrella        Pueblo Viejo               neighbourhood
# 5762  La estrella        Pueblo Viejo               neighbourhood
# 5779  La estrella            Yarumito               neighbourhood
# 5784  La estrella        Pueblo Viejo               neighbourhood
#
#       Metros Cuadrados  Metros Cuadrados Construidos  Estrato  ...  \
# 15                61.0                          61.0        0  ...
# 31                58.0                          58.0        0  ...
# 34                55.0                          55.0        0  ...
# 37                93.0                          93.0        0  ...
# 63                55.0                          55.0      110  ...
# ...                ...                           ...      ...  ...
# 5654             137.0                         137.0        0  ...
# 5741             865.0                         865.0        0  ...
# 5762              76.0                           NaN        0  ...
# 5779              87.0                          87.0        0  ...
# 5784             250.0                         250.0        0  ...
#
#       Es Oficina?  Es Penthouse?  Acepta Permuta?  (paid quota)?  \
# 15          False          False            False           True
# 31          False          False            False           True
# 34          False          False            False           True
# 37          False          False            False           True
# 63          False          False            False           True
# ...           ...            ...              ...            ...
# 5654        False          False            False           True
# 5741        False          False            False           True
# 5762        False          False            False           True
# 5779        False          False            False           True
# 5784        False          False            False           True
#
#       Fecha de Creacion de Oferta  Fecha de Actualización de Oferta  \
# 15                     2025-10-03                        2025-10-22
# 31                     2025-02-12                        2025-10-22
# 34                     2025-02-13                        2025-10-22
# 37                     2025-02-12                        2025-10-22
# 63                     2025-10-10                        2025-10-10
# ...                           ...                               ...
# 5654                   2025-09-08                        2025-10-22
# 5741                   2025-09-26                        2025-10-22
# 5762                   2025-10-15                        2025-10-23
# 5779                   2025-10-09                        2025-10-22
# 5784                   2025-10-10                        2025-11-01
#
#                                               Dirección  \
# 15             Apartamento en Venta en Comuna 10, Bello
# 31               Apartamento en  Venta en Centro, Bello
# 34         Apartamento en  Venta en Buenos aires, Bello
# 37            Apartamento en  Venta en Cabañitas, Bello
# 63               Apartamento en Venta en Cabañas, Bello
# ...                                                 ...
# 5654      Casa en Venta en Poblado Del Sur, La estrella
# 5741         Casa en Venta en Pueblo Viejo, La estrella
# 5762  Apartamento en Venta en Pueblo Viejo, La estrella
# 5779      Apartamento en Venta en Yarumito, La estrella
# 5784         Casa en Venta en Pueblo Viejo, La estrella
#
#                                                     URL  \
# 15    /apartamento-en-venta-en-comuna-10-bello/19294...
# 31      /apartamento-en-venta-en-centro-bello/192010579
# 34    /apartamento-en-venta-en-buenos-aires-bello/19...
# 37    /apartamento-en-venta-en-cabañitas-bello/19201...
# 63     /apartamento-en-venta-en-cabañas-bello/192971088
# ...                                                 ...
# 5654  /casa-en-venta-en-poblado-del-sur-la-estrella/...
# 5741  /casa-en-venta-en-pueblo-viejo-la-estrella/192...
# 5762  /apartamento-en-venta-en-pueblo-viejo-la-estre...
# 5779  /apartamento-en-venta-en-yarumito-la-estrella/...
# 5784  /casa-en-venta-en-pueblo-viejo-la-estrella/192...
#
#       Precio con Administración Incluida      Precio
# 15                             295224840   295000000
# 31                             305230000   305000000
# 34                             250255400   250000000
# 37                             420100000   420000000
# 63                             275200000   275000000
# ...                                  ...         ...
# 5654                           750353000   750000000
# 5741                           959000000   959000000
# 5762                           530270000   530000000
# 5779                           670350000   670000000
# 5784                          1700337000  1700000000
#
# [236 rows x 31 columns]

# %% [markdown]
# Encontramos que el hay 236 registros donde sus estratos no corresponden a los estandarizados por el gobierno, es decir registros erróneos

# %%
df[(df['Precio'] <= 100000000) |  (df['Precio'] > 100000000000)]
# Out:
#       ID de la propiedad Tipo de Operacion Tipo de Inmueble Departamento  \
# 2044           192989048             Venta      Apartamento    Antioquia
# 2477           193001539             Venta      Apartamento    Antioquia
# 3365           192451446             Venta      Apartamento    Antioquia
# 5244           192228606             Venta             Casa    Antioquia
# 5362           192570795             Venta      Apartamento    Antioquia
# 5474           192715365             Venta      Apartamento    Antioquia
#
#            Ciudad Localidad Principal Tipo de Localidad Principal  \
# 2044     Medellín         El chagualo               neighbourhood
# 2477     Medellín          El Poblado               neighbourhood
# 3365       Itaguí              Itaguí                        city
# 5244  La estrella         La estrella                        city
# 5362  La estrella          Suramérica               neighbourhood
# 5474  La estrella         La estrella                        city
#
#       Metros Cuadrados  Metros Cuadrados Construidos  Estrato  ...  \
# 2044             40.00                           NaN        3  ...
# 2477             76.00                         76.00        5  ...
# 3365             54.00                         54.00        4  ...
# 5244            159.00                        159.00        4  ...
# 5362             87.00                         87.00        4  ...
# 5474             50.27                         50.27        3  ...
#
#       Es Oficina?  Es Penthouse?  Acepta Permuta?  (paid quota)?  \
# 2044        False          False            False           True
# 2477        False          False            False           True
# 3365        False          False            False           True
# 5244        False          False            False           True
# 5362        False          False            False           True
# 5474        False          False            False          False
#
#       Fecha de Creacion de Oferta  Fecha de Actualización de Oferta  \
# 2044                   2025-10-16                        2025-10-24
# 2477                   2025-10-20                        2025-10-20
# 3365                   2025-05-26                        2025-05-26
# 5244                   2025-04-03                        2025-08-29
# 5362                   2025-06-26                        2025-09-04
# 5474                   2025-08-04                        2025-08-25
#
#                                             Dirección  \
# 2044    Apartamento en Venta en El chagualo, Medellín
# 2477     Apartamento en Venta en El Poblado, Medellín
# 3365                   Apartamento en Venta en Itaguí
# 5244                    Casa en  Venta en La estrella
# 5362  Apartamento en Venta en Suramérica, La estrella
# 5474              Apartamento en Venta en La estrella
#
#                                                     URL  \
# 2044  /apartamento-en-venta-en-el-chagualo-medellin/...
# 2477  /apartamento-en-venta-en-el-poblado-medellin/1...
# 3365          /apartamento-en-venta-en-itagui/192451446
# 5244            /casa-en-venta-en-la-estrella/192228606
# 5362  /apartamento-en-venta-en-suramerica-la-estrell...
# 5474     /apartamento-en-venta-en-la-estrella/192715365
#
#       Precio con Administración Incluida        Precio
# 2044                        250000000000  250000000000
# 2477                        474000000000  474000000000
# 3365                        347000192200  347000000000
# 5244                              390001             1
# 5362                        630000340000  630000000000
# 5474                            55000000      55000000
#
# [6 rows x 31 columns]

# %% [markdown]
# Curioso, dos casas muy baratas! Una de 1 peso y una de 55 millones. Ademas 4 casas sorprendentemente caras, seguramente sean precios erróneos

# %%
df['Cuartos (rooms)'].unique()
# Out:
# array([ 0,  3,  2,  4,  1,  6,  5,  7,  8, 10, 12, 15])

# %%
df['Baños'].unique()
# Out:
# array([ 2,  1,  3,  5,  4,  0,  6,  7,  9,  8, 10])

# %%
df['Dormitorios (bedrooms)'].unique()
# Out:
# array([ 3,  0,  1,  2,  4,  6,  5,  7,  8, 10, 12, 15])

# %% [markdown]
# Seguramente hay casas de 15 baños, pero quizas se pueda revisar. Se ve por el analisis de mahalanobis que estos numeros combinan con los metros cuadrados.

# %% [markdown]
# #### Duplicados

# %%
df.duplicated().sum()
# Out:
# np.int64(170)

# %% [markdown]
# Hay 170 registros duplicados, sin embargo quiero ver ademas segun el ID cuantos registros hay duplicados, y con el url

# %%
df['URL'].duplicated().sum()
# Out:
# np.int64(170)

# %%
df['ID de la propiedad'].duplicated().sum()
# Out:
# np.int64(170)

# %% [markdown]
# #### Integridad
#
# Debido a la fuente de los datos, no es necesario hacer un análisis de integridad
